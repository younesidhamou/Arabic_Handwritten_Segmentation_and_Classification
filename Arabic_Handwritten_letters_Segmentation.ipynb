# %%
from skimage import io
from skimage.transform import rotate
from skimage.color import rgb2gray
from deskew import determine_skew
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
import os

# %% [markdown]
# # Redressement

# %% [markdown]
# ### Exploration

# %%
im=cv2.imread("C:/Users/youne/OneDrive/Bureau/Datasets/ML/machine learning045.bmp")
#img=img.reshape(2328, 1664*3)

# %%
#fonction redressement l'image
def deskew(_img):
    image = _img
    angle = determine_skew(image)
    rotated = rotate(image, angle, resize=True) * 255
    return rotated.astype(np.uint8)

# %%
### pour la premiere page recadrer l'image

# %%
y=410
x=170
h=1450
w=2357-300
crop_image = im[x:w, y:h]

# %%
### Pour la dexieme page recadrer l'image

# %%
y1=400+150
x1=170+23
h1=1450-100
w1=2357-360
crop_image1 = img[x1:w1, y1:h1]

# %%
redressed_image=deskew(crop_image) # redressment de l'image
fig,axs = plt.subplots(1,2,figsize=(15,25))
axs[1].imshow(redressed_image)
axs[1].set_title('Après le redressement')
axs[0].imshow(crop_image)
axs[0].set_title('Avant le redressement')
# Out:
# Text(0.5, 1.0, 'Avant le redressement')

# %% [markdown]
# ### Enregistrement des resultats

# %%
import os
path = "C:/Users/youne/OneDrive/Bureau/Datasets/ML/"
dir_list = os.listdir(path)
from PIL import Image 
for file in dir_list:
    im=cv2.imread("C:/Users/youne/OneDrive/Bureau/Datasets/ML/"+file)
    img=deskew(im)
    if int(file[16:19])%2==0:
        crop_image = img[x1:w1, y1:h1]
    else:    
        crop_image = img[x:w, y:h]
    status=cv2.imwrite('C:/Users/youne/OneDrive/Bureau/Datasets/redressement+zonage/'+file,crop_image)
    print("Image written "+file+" : ",status)
# Out:
# Image written machine learning001.bmp :  True
# Image written machine learning002.bmp :  True
# Image written machine learning003.bmp :  True
# Image written machine learning004.bmp :  True
# Image written machine learning005.bmp :  True
# Image written machine learning006.bmp :  True
# Image written machine learning007.bmp :  True
# Image written machine learning008.bmp :  True
# Image written machine learning009.bmp :  True
# Image written machine learning010.bmp :  True
# Image written machine learning011.bmp :  True
# Image written machine learning012.bmp :  True
# Image written machine learning013.bmp :  True
# Image written machine learning014.bmp :  True
# Image written machine learning015.bmp :  True
# Image written machine learning016.bmp :  True
# Image written machine learning017.bmp :  True
# Image written machine learning018.bmp :  True
# Image written machine learning019.bmp :  True
# Image written machine learning020.bmp :  True
# ...

# %% [markdown]
# ### Exploration

# %%
im=cv2.imread("C:/Users/youne/OneDrive/Bureau/Datasets/ML/machine learning044.bmp")
Binerised_image= cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
fig,axs = plt.subplots(1,2,figsize=(15,25))
axs[1].imshow(Binerised_image,cmap="gray")
axs[1].set_title('Après la binarisation')
axs[0].imshow(im)
axs[0].set_title('Avant la binarisation')
# Out:
# Text(0.5, 1.0, 'Avant la binarisation')

# %% [markdown]
# ### Enregistrement des resultats

# %%
path = "C:/Users/youne/OneDrive/Bureau/Datasets/redressement+zonage/"
dir_list = os.listdir(path)
from PIL import Image 
for file in dir_list:
    im=cv2.imread("C:/Users/youne/OneDrive/Bureau/Datasets/redressement+zonage/"+file)
    grayImage = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    status=cv2.imwrite('C:/Users/youne/OneDrive/Bureau/Datasets/binarization/'+file,grayImage)
    print("Image written "+file+" : ",status)
# Out:
# Image written machine learning001.bmp :  True
# Image written machine learning002.bmp :  True
# Image written machine learning003.bmp :  True
# Image written machine learning004.bmp :  True
# Image written machine learning005.bmp :  True
# Image written machine learning006.bmp :  True
# Image written machine learning007.bmp :  True
# Image written machine learning008.bmp :  True
# Image written machine learning009.bmp :  True
# Image written machine learning010.bmp :  True
# Image written machine learning011.bmp :  True
# Image written machine learning012.bmp :  True
# Image written machine learning013.bmp :  True
# Image written machine learning014.bmp :  True
# Image written machine learning015.bmp :  True
# Image written machine learning016.bmp :  True
# Image written machine learning017.bmp :  True
# Image written machine learning018.bmp :  True
# Image written machine learning019.bmp :  True
# Image written machine learning020.bmp :  True
# ...

# %% [markdown]
# # Zonage

# %% [markdown]
# ### Exploration

# %%
#la premiere page: 
# la zone 1
y5=0
x5=0
h5=190
w5=2000
# la zone 2 
y6=250
x6=0
h6=410
w6=2000
# la zone 3
y7=490
x7=0
h7=630
w7=2000
# la zone 4
y8=700
x8=0
h8=160+230+150+230+240
w8=2000

# %%
#la deuxieme page:
# la zone 1 
y1=130
x1=0
h1=290
w1=2000
# la zone 2
y2=370
x2=0
h2=520
w2=2000
# la zone 3 
y3=600
x3=0
h3=760
w3=2000
# la zone 4
y4=830
x4=0
h4=1000
w4=2000

# %% [markdown]
# ### Enregistrement des resultats

# %%
from PIL import Image 
count=0
path = "C:/Users/youne/OneDrive/Bureau/Datasets/redressement+zonage/"
dir_list = os.listdir(path)
for file in dir_list:
    im=cv2.imread("C:/Users/youne/OneDrive/Bureau/Datasets/redressement+zonage/"+file)
    if int(file[16:19])%2==0:
        crop_image1 = im[x5:w5, y5:h5]
        crop_image2 = im[x6:w6, y6:h6]
        crop_image3 = im[x7:w7, y7:h7]
        crop_image4 = im[x8:w8, y8:h8]
    else:    
        crop_image1 = im[x1:w1, y1:h1]
        crop_image2 = im[x2:w2, y2:h2]
        crop_image3 = im[x3:w3, y3:h3]
        crop_image4 = im[x4:w4, y4:h4]
    count=0
    cv2.imwrite('C:/Users/youne/OneDrive/Bureau/Datasets/zonage/'+str(count)+"_"+file,crop_image1)
    count=count+1
    cv2.imwrite('C:/Users/youne/OneDrive/Bureau/Datasets/zonage/'+str(count)+"_"+file,crop_image2)
    count=count+1
    cv2.imwrite('C:/Users/youne/OneDrive/Bureau/Datasets/zonage/'+str(count)+"_"+file,crop_image3)
    count=count+1
    cv2.imwrite('C:/Users/youne/OneDrive/Bureau/Datasets/zonage/'+str(count)+"_"+file,crop_image4)

# %% [markdown]
# ### Visualisation les resultats

# %%
path = "C:/Users/youne/OneDrive/Bureau/Datasets/ROI_2/"
dir_list = os.listdir(path)
im1=cv2.imread(path+dir_list[0])
im2=cv2.imread(path+dir_list[4])
im3=cv2.imread(path+dir_list[2])
im4=cv2.imread(path+dir_list[3])
fig,axs = plt.subplots(4,figsize=(25,15))
axs[0].imshow(cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[0].set_title('la zone 1')
axs[1].imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[1].set_title('la zone 2')
axs[2].imshow(cv2.cvtColor(im3, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[2].set_title('la zone 3')
axs[3].imshow(cv2.cvtColor(im4, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[3].set_title('la zone 4')
# Out:
# Text(0.5, 1.0, 'la zone 4')

# %% [markdown]
# ## Correction

# %% [markdown]
# ### Remove vertical lines

# %%
import cv2
from tqdm import tqdm
path = "C:/Users/youne/OneDrive/Bureau/Datasets/clear_ML/"
dir_list = os.listdir(path)
for file in tqdm(dir_list):
    image = cv2.imread("C:/Users/youne/OneDrive/Bureau/Datasets/clear_ML/"+file)
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,40))
    detected_lines = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel, iterations=1)
    cnts = cv2.findContours(detected_lines, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    for c in cnts:
        cv2.drawContours(image, [c], -1, (255,255,255), 2)
    try:
    #cv2.imwrite('ROI.png', ROI)
        cv2.imwrite("C:/Users/youne/OneDrive/Bureau/Datasets/words/"+file,image)
    except:
        continue
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 111/111 [00:00<00:00, 258.23it/s]

# %% [markdown]
# ### Visualisation des resultats

# %%
path = "C:/Users/youne/OneDrive/Bureau/Datasets/words/"
dir_list = os.listdir(path)
im1=cv2.imread(path+dir_list[0])
im2=cv2.imread(path+dir_list[4])
im3=cv2.imread(path+dir_list[2])
im4=cv2.imread(path+dir_list[3])
fig,axs = plt.subplots(4,figsize=(25,15))
axs[0].imshow(cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[0].set_title('la zone 1')
axs[1].imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[1].set_title('la zone 2')
axs[2].imshow(cv2.cvtColor(im3, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[2].set_title('la zone 3')
axs[3].imshow(cv2.cvtColor(im4, cv2.COLOR_BGR2GRAY),cmap="gray")
axs[3].set_title('la zone 4')
# Out:
# Text(0.5, 1.0, 'la zone 4')

# %% [markdown]
# # Segmentation

# %% [markdown]
# ### Word extraction

# %%
path = "C:/Users/youne/OneDrive/Bureau/Datasets/words/"
dir_list = os.listdir(path)
img=cv2.imread(path+dir_list[0])
def thresholding(image):
    img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(img_gray,200,255,cv2.THRESH_BINARY_INV)
    plt.figure(figsize = (20,30))
    plt.imshow(cv2.cvtColor(thresh,cv2.COLOR_BGR2RGB))
    return thresh

thresh_img = thresholding(img);

# %%
kernel = np.ones((2,4), np.uint8)
dilated = cv2.dilate(thresh_img, kernel, iterations = 7)
plt.figure(figsize = (20,30))
plt.imshow(dilated,cmap="gray");

# %%
(contours, heirarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
sorted_contours_lines = sorted(contours, key = lambda ctr : cv2.boundingRect(ctr)[1]) # (x, y, w, h)

# %%
#dilation
kernel = np.ones((4,6), np.uint8)
dilated2 = cv2.dilate(dilated, kernel, iterations = 11)
plt.figure(figsize = (20,30))
plt.imshow(dilated2, cmap='gray');

# %%
img3 = img.copy()
words_list = []

for line in sorted_contours_lines:
    
    # roi of each line
    x, y, w, h = cv2.boundingRect(line)
    roi_line = dilated2[y:y+w, x:x+w]
    
    # draw contours on each word
    (cnt, heirarchy) = cv2.findContours(roi_line.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    sorted_contour_words = sorted(cnt, key=lambda cntr : cv2.boundingRect(cntr)[0])
    
    for word in sorted_contour_words:
        
        if cv2.contourArea(word) < 400:
            continue
        
        x2, y2, w2, h2 = cv2.boundingRect(word)
        words_list.append([x+x2, y+y2, x+x2+w2, y+y2+h2])
        cv2.rectangle(img3, (x+x2-15, y+y2-30), (x+x2+w2, y+y2+h2+10), (255,255,100),2)
plt.figure(figsize = (20,30))        
plt.imshow(img3);

# %% [markdown]
# ### Enregistrement des resultats

# %%
dir_list = os.listdir('C:/Users/youne/OneDrive/Bureau/Datasets/words/')
count=0
for file in dir_list:
    img = cv2.imread('C:/Users/youne/OneDrive/Bureau/Datasets/words/'+file)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    h, w, c = img.shape

    if w > 1000:

        new_w = 1000
        ar = w/h
        new_h = int(new_w/ar)

        img = cv2.resize(img, (new_w, new_h), interpolation = cv2.INTER_AREA)
    thresh_img = thresholding(img);
    kernel = np.ones((3,15), np.uint8)
    dilated2 = cv2.dilate(thresh_img, kernel, iterations = 2)
    img3 = img.copy()
    words_list = []

    for line in sorted_contours_lines:

        # roi of each line
        x, y, w, h = cv2.boundingRect(line)
        roi_line = dilated2[y:y+w, x:x+w]

        # draw contours on each word
        (cnt, heirarchy) = cv2.findContours(roi_line.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        sorted_contour_words = sorted(cnt, key=lambda cntr : cv2.boundingRect(cntr)[0])

        for word in sorted_contour_words:

            if cv2.contourArea(word) < 400:
                continue

            x2, y2, w2, h2 = cv2.boundingRect(word)
            words_list.append([x+x2, y+y2, x+x2+w2, y+y2+h2])
            cv2.rectangle(img3, (x+x2-15, y+y2-30), (x+x2+w2, y+y2+h2+10), (255,255,100),2)

    for word in words_list:
        ninth_word = word
        roi_9 = img[ninth_word[1]:ninth_word[3], ninth_word[0]:ninth_word[2]]
        cv2.imwrite("C:/Users/youne/OneDrive/Bureau/Datasets/chars/word_"+str(count)+".png", roi_9)
        count=count+1

# %% [markdown]
# ### Visualisation des resultats

# %%
path = "C:/Users/youne/OneDrive/Bureau/Datasets/chars/"
dir_list = os.listdir(path)
im1=cv2.imread(path+dir_list[0])
im2=cv2.imread(path+dir_list[1])
im3=cv2.imread(path+dir_list[2])
thresholding(im1)
thresholding(im2)
thresholding(im3)
plt.show()

# %% [markdown]
# ### Extract characters

# %%
img = cv2.imread('C:/Users/youne/OneDrive/Bureau/Datasets/chars/word_0.png')
thresh_img=thresholding(img)

# %%
kernel = np.ones((1,5), np.uint8)
dilated = cv2.dilate(thresh_img, kernel, iterations = 1)
plt.figure(figsize = (20,30))
plt.imshow(dilated, cmap='gray');

# %%
(contours, heirarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
sorted_contours_lines = sorted(contours, key = lambda ctr : cv2.boundingRect(ctr)[1]) # (x, y, w, h)

# %%
#dilation
kernel = np.ones((3,1), np.uint8)
dilated2 = cv2.dilate(dilated, kernel, iterations = 1)
plt.figure(figsize = (20,30))
plt.imshow(dilated2, cmap='gray');

# %%
img3 = img.copy()
words_list = []

for line in sorted_contours_lines:
    
    # roi of each line
    x, y, w, h = cv2.boundingRect(line)
    roi_line = dilated2[y:y+w, x:x+w]
    
    # draw contours on each word
    (cnt, heirarchy) = cv2.findContours(roi_line.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    sorted_contour_words = sorted(cnt, key=lambda cntr : cv2.boundingRect(cntr)[0])
    
    for word in sorted_contour_words:
        
        if cv2.contourArea(word) < 90:
            continue
        
        x2, y2, w2, h2 = cv2.boundingRect(word)
        words_list.append([x+x2, y+y2, x+x2+w2, y+y2+h2])
        cv2.rectangle(img3, (x+x2, y+y2-20), (x+x2+w2, y+y2+h2+20), (255,255,100),2)
plt.figure(figsize = (20,30))        
plt.imshow(img3);

# %%
dir_list = os.listdir('C:/Users/youne/OneDrive/Bureau/Datasets/chars/')
count=0
for file in dir_list:
    img = cv2.imread('C:/Users/youne/OneDrive/Bureau/Datasets/chars/'+file)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    h, w, c = img.shape

    if w > 1000:

        new_w = 1000
        ar = w/h
        new_h = int(new_w/ar)

        img = cv2.resize(img, (new_w, new_h), interpolation = cv2.INTER_AREA)
    thresh_img = thresholding(img);
    #dilation
    kernel = np.ones((3,5), np.uint8)
    dilated2 = cv2.dilate(thresh_img, kernel, iterations = 1)
    img3 = img.copy()
    words_list = []

    for line in sorted_contours_lines:

        # roi of each line
        x, y, w, h = cv2.boundingRect(line)
        roi_line = dilated2[y:y+w, x:x+w]

        # draw contours on each word
        (cnt, heirarchy) = cv2.findContours(roi_line.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        sorted_contour_words = sorted(cnt, key=lambda cntr : cv2.boundingRect(cntr)[0])

        for word in sorted_contour_words:

            if cv2.contourArea(word) < 90:
                continue

            x2, y2, w2, h2 = cv2.boundingRect(word)
            words_list.append([x+x2, y+y2, x+x2+w2, y+y2+h2])
            cv2.rectangle(img3, (x+x2, y+y2-20), (x+x2+w2, y+y2+h2+20), (255,255,100),2)

    for word in words_list:
        ninth_word = word
        roi_9 = img[ninth_word[1]:ninth_word[3], ninth_word[0]:ninth_word[2]]
        cv2.imwrite("C:/Users/youne/OneDrive/Bureau/Datasets/me_1/word_"+str(count)+".png", roi_9)
        count=count+1
